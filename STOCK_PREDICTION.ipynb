# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('stock.csv')

# %%
df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
print(df.shape)
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']]
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))

# %%
df.set_index('Date',drop=True,inplace=True)
df.head(5)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='black')
ax[0].set_xlabel('Year',size=20)
ax[0].set_ylabel('Price',size=20)
ax[0].legend()
ax[1].plot(df['Close'],label='Close',color='blue')
ax[1].set_xlabel('Year',size=20)
ax[1].set_ylabel('Price',size=20)
ax[1].legend()
fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
training_size = round(len(df) * 0.75)
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data = df[training_size:]
train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.
 shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam',
 metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq,
 test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 8s 115ms/step - loss: 0.0365 - mean_absolute_error: 0.1372 - val_loss: 0.0568 - val_mean_absolute_error: 0.2230
# Epoch 2/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - val_loss: 0.0135 - val_mean_absolute_error: 0.0971
# Epoch 3/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0027 - mean_absolute_error: 0.0398 - val_loss: 0.0062 - val_mean_absolute_error: 0.0532
# Epoch 4/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 0.0073 - val_mean_absolute_error: 0.0591
# Epoch 5/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0022 - mean_absolute_error: 0.0361 - val_loss: 0.0053 - val_mean_absolute_error: 0.0498
# Epoch 6/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 0.0051 - val_mean_absolute_error: 0.0489
# Epoch 7/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0060 - val_mean_absolute_error: 0.0526
# Epoch 8/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0024 - mean_absolute_error: 0.0367 - val_loss: 0.0048 - val_mean_absolute_error: 0.0465
# Epoch 9/100
# 23/23 [==============================] - 2s 85ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 0.0048 - val_mean_absolute_error: 0.0494
# Epoch 10/100
# 23/23 [==============================] - 2s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 0.0043 - val_mean_absolute_error: 0.0442
# Epoch 11/100
# 23/23 [==============================] - 1s 63ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 0.0042 - val_mean_absolute_error: 0.0455
# Epoch 12/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0019 - mean_absolute_error: 0.0324 - val_loss: 0.0039 - val_mean_absolute_error: 0.0418
# Epoch 13/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0018 - mean_absolute_error: 0.0312 - val_loss: 0.0036 - val_mean_absolute_error: 0.0399
# Epoch 14/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0018 - mean_absolute_error: 0.0315 - val_loss: 0.0033 - val_mean_absolute_error: 0.0387
# Epoch 15/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0031 - val_mean_absolute_error: 0.0379
# Epoch 16/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 0.0030 - val_mean_absolute_error: 0.0360
# Epoch 17/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0017 - mean_absolute_error: 0.0310 - val_loss: 0.0041 - val_mean_absolute_error: 0.0440
# Epoch 18/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.0017 - mean_absolute_error: 0.0307 - val_loss: 0.0028 - val_mean_absolute_error: 0.0344
# Epoch 19/100
# 23/23 [==============================] - 2s 66ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0029 - val_mean_absolute_error: 0.0368
# Epoch 20/100
# 23/23 [==============================] - 2s 88ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0026 - val_mean_absolute_error: 0.0331
# Epoch 21/100
# 23/23 [==============================] - 2s 87ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 0.0026 - val_mean_absolute_error: 0.0340
# Epoch 22/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0033 - val_mean_absolute_error: 0.0441
# Epoch 23/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0029 - val_mean_absolute_error: 0.0354
# Epoch 24/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 0.0022 - val_mean_absolute_error: 0.0297
# Epoch 25/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 0.0021 - val_mean_absolute_error: 0.0288
# Epoch 26/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 0.0022 - val_mean_absolute_error: 0.0298
# Epoch 27/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - val_loss: 0.0021 - val_mean_absolute_error: 0.0298
# Epoch 28/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 0.0020 - val_mean_absolute_error: 0.0296
# Epoch 29/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0012 - mean_absolute_error: 0.0251 - val_loss: 0.0020 - val_mean_absolute_error: 0.0274
# Epoch 30/100
# 23/23 [==============================] - 2s 86ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
# Epoch 31/100
# 23/23 [==============================] - 2s 86ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 0.0021 - val_mean_absolute_error: 0.0314
# Epoch 32/100
# 23/23 [==============================] - 2s 75ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 0.0019 - val_mean_absolute_error: 0.0275
# Epoch 33/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 0.0019 - val_mean_absolute_error: 0.0295
# Epoch 34/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 0.0017 - val_mean_absolute_error: 0.0259
# Epoch 35/100
# 23/23 [==============================] - 1s 55ms/step - loss: 9.8212e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0021 - val_mean_absolute_error: 0.0300
# Epoch 36/100
# 23/23 [==============================] - 1s 52ms/step - loss: 9.7540e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0017 - val_mean_absolute_error: 0.0267
# Epoch 37/100
# 23/23 [==============================] - 1s 54ms/step - loss: 9.3097e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0017 - val_mean_absolute_error: 0.0272
# Epoch 38/100
# 23/23 [==============================] - 1s 56ms/step - loss: 9.2907e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 39/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 0.0019 - val_mean_absolute_error: 0.0315
# Epoch 40/100
# 23/23 [==============================] - 2s 67ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 0.0016 - val_mean_absolute_error: 0.0254
# Epoch 41/100
# 23/23 [==============================] - 2s 89ms/step - loss: 8.5782e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0015 - val_mean_absolute_error: 0.0234
# Epoch 42/100
# 23/23 [==============================] - 3s 116ms/step - loss: 8.0946e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0015 - val_mean_absolute_error: 0.0233
# Epoch 43/100
# 23/23 [==============================] - 1s 57ms/step - loss: 8.2302e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0230
# Epoch 44/100
# 23/23 [==============================] - 1s 52ms/step - loss: 8.5156e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0015 - val_mean_absolute_error: 0.0262
# Epoch 45/100
# 23/23 [==============================] - 1s 54ms/step - loss: 7.8135e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0013 - val_mean_absolute_error: 0.0229
# Epoch 46/100
# 23/23 [==============================] - 1s 55ms/step - loss: 8.3683e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0015 - val_mean_absolute_error: 0.0280
# Epoch 47/100
# 23/23 [==============================] - 1s 56ms/step - loss: 8.2481e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0013 - val_mean_absolute_error: 0.0219
# Epoch 48/100
# 23/23 [==============================] - 1s 52ms/step - loss: 8.4957e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 49/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 0.0013 - val_mean_absolute_error: 0.0215
# Epoch 50/100
# 23/23 [==============================] - 2s 66ms/step - loss: 9.4179e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0013 - val_mean_absolute_error: 0.0215
# Epoch 51/100
# 23/23 [==============================] - 2s 87ms/step - loss: 6.8694e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0015 - val_mean_absolute_error: 0.0278
# Epoch 52/100
# 23/23 [==============================] - 2s 92ms/step - loss: 7.2868e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0014 - val_mean_absolute_error: 0.0235
# Epoch 53/100
# 23/23 [==============================] - 1s 55ms/step - loss: 7.1864e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0019 - val_mean_absolute_error: 0.0299
# Epoch 54/100
# 23/23 [==============================] - 1s 53ms/step - loss: 8.9096e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0014 - val_mean_absolute_error: 0.0226
# Epoch 55/100
# 23/23 [==============================] - 1s 53ms/step - loss: 7.3809e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 56/100
# 23/23 [==============================] - 1s 53ms/step - loss: 7.0525e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 57/100
# 23/23 [==============================] - 1s 55ms/step - loss: 7.2300e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 58/100
# 23/23 [==============================] - 1s 52ms/step - loss: 7.8157e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0011 - val_mean_absolute_error: 0.0201
# Epoch 59/100
# 23/23 [==============================] - 1s 53ms/step - loss: 6.9095e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0011 - val_mean_absolute_error: 0.0209
# Epoch 60/100
# 23/23 [==============================] - 1s 55ms/step - loss: 6.8750e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# Epoch 61/100
# 23/23 [==============================] - 2s 89ms/step - loss: 6.8217e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0023 - val_mean_absolute_error: 0.0409
# Epoch 62/100
# 23/23 [==============================] - 2s 89ms/step - loss: 7.0521e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0012 - val_mean_absolute_error: 0.0234
# Epoch 63/100
# 23/23 [==============================] - 2s 71ms/step - loss: 7.1387e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0012 - val_mean_absolute_error: 0.0236
# Epoch 64/100
# 23/23 [==============================] - 1s 57ms/step - loss: 6.3115e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0011 - val_mean_absolute_error: 0.0221
# Epoch 65/100
# 23/23 [==============================] - 2s 79ms/step - loss: 6.0931e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 66/100
# 23/23 [==============================] - 1s 56ms/step - loss: 6.1626e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0010 - val_mean_absolute_error: 0.0192
# Epoch 67/100
# 23/23 [==============================] - 1s 57ms/step - loss: 7.1799e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 68/100
# 23/23 [==============================] - 1s 53ms/step - loss: 7.1167e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 69/100
# 23/23 [==============================] - 1s 55ms/step - loss: 5.8060e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0011 - val_mean_absolute_error: 0.0204
# Epoch 70/100
# 23/23 [==============================] - 1s 55ms/step - loss: 5.9105e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0011 - val_mean_absolute_error: 0.0197
# Epoch 71/100
# 23/23 [==============================] - 2s 91ms/step - loss: 6.6359e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0012 - val_mean_absolute_error: 0.0219
# Epoch 72/100
# 23/23 [==============================] - 2s 85ms/step - loss: 7.0013e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 73/100
# 23/23 [==============================] - 2s 66ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 0.0015 - val_mean_absolute_error: 0.0262
# Epoch 74/100
# 23/23 [==============================] - 1s 54ms/step - loss: 7.8520e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0224
# Epoch 75/100
# 23/23 [==============================] - 1s 56ms/step - loss: 6.5469e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0013 - val_mean_absolute_error: 0.0251
# Epoch 76/100
# 23/23 [==============================] - 1s 53ms/step - loss: 6.1258e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0013 - val_mean_absolute_error: 0.0249
# Epoch 77/100
# 23/23 [==============================] - 1s 53ms/step - loss: 6.0597e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0011 - val_mean_absolute_error: 0.0214
# Epoch 78/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.6892e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0013 - val_mean_absolute_error: 0.0260
# Epoch 79/100
# 23/23 [==============================] - 1s 56ms/step - loss: 6.3303e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 80/100
# 23/23 [==============================] - 1s 58ms/step - loss: 6.2236e-04 - mean_absolute_error: 0.0178 - val_loss: 9.6515e-04 - val_mean_absolute_error: 0.0182
# Epoch 81/100
# 23/23 [==============================] - 2s 85ms/step - loss: 5.9899e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0010 - val_mean_absolute_error: 0.0205
# Epoch 82/100
# 23/23 [==============================] - 2s 88ms/step - loss: 6.2395e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 83/100
# 23/23 [==============================] - 2s 77ms/step - loss: 7.2927e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 84/100
# 23/23 [==============================] - 1s 57ms/step - loss: 6.0161e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0011 - val_mean_absolute_error: 0.0214
# Epoch 85/100
# 23/23 [==============================] - 1s 59ms/step - loss: 5.6105e-04 - mean_absolute_error: 0.0169 - val_loss: 9.8051e-04 - val_mean_absolute_error: 0.0188
# Epoch 86/100
# 23/23 [==============================] - 1s 57ms/step - loss: 5.4314e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0011 - val_mean_absolute_error: 0.0204
# Epoch 87/100
# 23/23 [==============================] - 1s 53ms/step - loss: 6.0479e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 88/100
# 23/23 [==============================] - 1s 55ms/step - loss: 5.6268e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 89/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.7895e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0027 - val_mean_absolute_error: 0.0444
# Epoch 90/100
# 23/23 [==============================] - 1s 57ms/step - loss: 8.2453e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 91/100
# 23/23 [==============================] - 2s 70ms/step - loss: 5.6518e-04 - mean_absolute_error: 0.0168 - val_loss: 9.8457e-04 - val_mean_absolute_error: 0.0190
# Epoch 92/100
# 23/23 [==============================] - 2s 95ms/step - loss: 5.1729e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0010 - val_mean_absolute_error: 0.0205
# Epoch 93/100
# 23/23 [==============================] - 2s 84ms/step - loss: 5.6751e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255
# Epoch 94/100
# 23/23 [==============================] - 1s 55ms/step - loss: 5.6729e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 95/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.5253e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 96/100
# 23/23 [==============================] - 1s 56ms/step - loss: 6.2059e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0011 - val_mean_absolute_error: 0.0225
# Epoch 97/100
# 23/23 [==============================] - 1s 56ms/step - loss: 5.6611e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0011 - val_mean_absolute_error: 0.0207
# Epoch 98/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.8396e-04 - mean_absolute_error: 0.0170 - val_loss: 8.7856e-04 - val_mean_absolute_error: 0.0174
# Epoch 99/100
# 23/23 [==============================] - 1s 58ms/step - loss: 5.2694e-04 - mean_absolute_error: 0.0163 - val_loss: 9.8519e-04 - val_mean_absolute_error: 0.0193
# Epoch 100/100
# 23/23 [==============================] - 1s 55ms/step - loss: 5.7426e-04 - mean_absolute_error: 0.0170 - val_loss: 9.0927e-04 - val_mean_absolute_error: 0.0181

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 14ms/step
# array([[0.70129645, 0.6916124 ],
#        [0.62184554, 0.61871004],
#        [0.6082704 , 0.60549825],
#        [0.6091087 , 0.60555094],
#        [0.61826   , 0.6134481 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[555.41534, 550.5071 ],
#        [518.9926 , 517.13165],
#        [512.7694 , 511.08316],
#        [513.1537 , 511.10727],
#        [517.34894, 514.72266]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-202:].copy(),
                           pd.
   DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-202:].index)], axis=1)

# %%
df_merge[['Open','Close']] = MMS.inverse_transform(df_merge[['Open','Close']])
df_merge.head()
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      555.415344       550.507080
# 2021-04-22  513.820007  508.779999      518.992615       517.131653
# 2021-04-23  509.010010  505.549988      512.769409       511.083160
# 2021-04-26  506.760010  510.299988      513.153687       511.107269
# 2021-04-27  512.619995  505.549988      517.348938       514.722656

# %%
df_merge[['Open','open_predicted']].plot(figsize=(10,6),color=['purple','orange'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual Open Price vs Predicted Open Price',size=20)
plt.show()

# %%
df_merge[['Close','close_predicted']].plot(figsize=(10,6),color=['darkgreen','red'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual close price vs Predicted close price',size=20)
plt.show()

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                   Open       Close  open_predicted  close_predicted
# 2021-06-09  494.500000  485.809998      499.839630       496.880341
# 2021-06-10  487.170013  487.269989      494.458008       491.917969
# 2021-06-11  490.000000  488.769989      492.780396       490.290771
# 2021-06-14  489.679993  499.890015      494.559448       491.840210
# 2021-06-15  501.230011  491.899994      502.786255       499.347626
# 2021-06-16  495.000000  492.410004      501.221924       497.998566

# %%
upcoming_prediction = pd.DataFrame(columns=['Open','Close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
upcoming_prediction[['Open','Close']] = MMS.inverse_transform(upcoming_prediction[['Open','Close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming Open price prediction',size=20)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming close price prediction',size=20)
ax.legend()
fig.show()
